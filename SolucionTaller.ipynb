# %% [markdown]
# # Taller 3
#
# Luisa Quiroga 625104<br>
# Fabio Castillo 624018<br>
# William Rincon 624959<br>

# %% [markdown]
# ##Punto 1 Teoría estadística y simulación

# %% [markdown]
# a) Distribución Gamma
#
# FDP
#
# \begin{align}
#     f_X(x)=\frac{{x^{k-1}e^{{-x}/{\theta}}}}{\theta^k\Gamma(k)}
# \end{align}
#
# donde
#
# \begin{align}
#    \Gamma(k)=\int_{0}^{\infty}u^{k-1}e^{-u}du
# \end{align}
#
# Con lo cual se halla que el valor esperado es
# \begin{align}
# E[X]=\int_{0}^{\infty}xf(x)dx=\int_{0}^{\infty}\frac{x^ke^{-x/\theta}}{\theta^k\Gamma(k)}dx=\frac{1}{\theta^k\Gamma(k)}\int_{0}^{\infty}x^ke^{-x/\theta}dx
# \end{align}
# Por sustitución
# \begin{align}
# u=\frac{x}{\theta}  du=\frac{1}{\theta}
# \end{align}
#
# \begin{align}
# =\frac{1}{\theta^k\Gamma(k)}\int_{0}^{\infty}(u\theta)^ke^{-u}\theta du=\frac{\theta^k\theta}{\theta^k\Gamma(k)}\int_{0}^{\infty}u^ke^{-u}du
# \end{align}
#
# Ahora, por deficinición de la función Gamma
# \begin{align}
# \Gamma(k)=\int_{0}^{infty}u^{k-1}e^{-u}du
# \end{align}
# Entonces
# \begin{align}
# \int_{0}^{\infty}u^{k}e^{-u}du=\Gamma(k+1)
# \end{align}
# Lo que puedo simplificar integrando por partes
# \begin{align}
# u=u^k \ \ du=ku^{k-1}
# \end{align}
# \begin{align}
# dv=e^{-u} \ \ v=-e^{-u}
# \end{align}
# \begin{align}
# =u^ke^-u|_0^\infty - \int_{0}^{\infty}-e^{-u}ku^{k-1}
# \end{align}
# Lo que podemos evavluar así
# \begin{align}
# \displaystyle\lim{u \to \infty}{u^ke^{-u}-0^ke^0} +k\Gamma(k)= \lim{u \to \infty}\frac{u^k}{e^u}+k\Gamma(k)
# \end{align}
# Hago L'Hopital k veces hasta que en el numerador queda una constante
# \begin{align}
# \lim{u \to \infty}\frac{C}{e^u}=0
# \end{align}
# entonces
# \begin{align}
# \frac{\theta k\Gamma(k)}{\Gamma(k)}=\theta k
# \end{align}

# %% [markdown]
# y la varianza
# \begin{align}
# \sigma^2=E[x^2]-(E[x])^2
# \end{align}
#
# Hallamos  el valor de $E[x^2]$
#
# \begin{align}
# E[x^2]=\int_{0}^{\infty}x^2f(x)=\int_{0}^{\infty}\frac{x^2x^{k-1}e^{x/\theta}}{\theta^k\Gamma(k)}dx=\frac{1}{\theta^k\Gamma(k)}\int_{0}^{\infty}x^{k+1}e^{-x/\theta}dx
# \end{align}
# Por sustitución
#
# $y=\frac{x}{\theta} \ \ dy=\frac{1}{\theta}dx$
#
# \begin{align}
# \frac{1}{\theta^k\Gamma(k)}\int_{0}^{\infty}(\theta y)^{k+1}e^{-xy}\theta dy =\frac{\theta ^{k+1}}{\theta^k\Gamma(k)}\int_{0}^{\infty}y^{k+1}e^{y}\theta dy
# \end{align}
# \begin{align}
# =\frac{{\theta}}{\Gamma(k)}\int_{0}^{\infty}y^{k+1}e^{-y}dy
# \end{align}
# Ahora, tengo que <br>
# $ \Gamma(k+2)=\int_{0}^{\infty}y^{k+1}e^{-y}dy $<br>
# derivo por partes<br>
# $u=y^{k+1} \ \ du=(k+1)y^k$<br>
# $dv=e^{-y} \ \ v=-e^{-y}$<br>
#
# \begin{align}
# =-y^{k+1}e^{-y}|_{0}^{\infty}-\int_{0}^{\infty}-e^{-y}(k+1)y^kdy
# \end{align}
# Se hace l'Hopital k+1 veces en el numerador queda una constante<br>
# $lim_{y \to \infty}\frac{-C}{e^y}=0$
# entonces <br>
# \begin{align}
# \frac{\theta^2}{\Gamma(k)}(k+1)\Gamma(k+1)
# \end{align}
# Antes se demostro $\Gamma(k+1)=k\Gamma(k)$
# \begin{align}
# \frac{\theta^2}{\Gamma(k)}(k+1)k\Gamma(k)=\theta^2(k+1)k=\theta^2(k^2+k)
# \end{align}
# Con respecto a la otra parte de la ecuación
# \begin{align}
# E[x]^2=(\theta k)^2
# \end{align}
# Unimos todo
# \begin{align}
# \sigma^2=\theta^2(k^2-k)-\theta^2k^2=k^2\theta^2+k\theta^2-\theta^2k^2=k\theta^2
# \end{align}

# %% [markdown]
# b) Distribución exponencial
#
# Valor esperado para la distribucion exponencial
# \begin{align}
# E[x]=\int_{0}^{\infty}x(\frac{1}{\theta}e^{-x/\theta})dx
# \end{align}
# Por sustitucion<br>$u=x \ \ du=dx$<br>$dv=\frac{1}{\theta}e^{-x/\theta} \ \ v=\frac{-\theta}{e^{-x/\theta}}$
# \begin{align}
# =-xe^{-x/\theta}|_{0}^{\infty}-\int_{0}^{\infty}-e^{x/\theta}dx=-\theta e^{-x/\theta}|_{0}^{\infty}=\lim_{x}\to{\infty}-\theta e^{-x/\theta}=\theta
# \end{align}
#
# Varianza
#
# \begin{align}
# \sigma^2=(E[X^2])-(E[X])^2
# E[x^2]=\int_{0}^{\infty}x^2(\frac{1}{\theta}e^{-x/\theta})dx
# \end{align}
# Por sustitución trigonométrica<br>
# $u=x^2 \ \ du=2xdx$<br>
# $dv=\frac{1}{\theta}e^{-x/\theta} \ \ v=-e^(-x/\theta)$
# \begin{align}
# =-x^2e^{-x/\theta}-\int_{0}^{\infty}-2xe^{-x/\theta}
# \end{align}
# de nuevo hacemos sustitución<br>
# $u=2x \ \ du=2dx$<br>
# $dv=e^{-x/\theta} \ \ v=-e^(-x/\theta)$
#
# \begin{align}
# =-2x\theta e^{-x/\theta}-\int_{0}^{\infty}-2\theta e^{x/\theta}dx = -2\theta^2e^{-x/\theta}|_{0}^{\infty}=0+2\theta^2
# \end{align}
# Uniendo todo
# \begin{align}
# \sigma^2=2\theta^2-\theta2=\theta^2
# \end{align}

# %% [markdown]
# ##Punto 2
#
# a) El valor esperado de lanzar dos dados de 6 caras es el valor que se puede obtener al lazarlo, por la probabilidad de obtenerlo el valor, se pueden obtener 36 posibles combinaciones
#
# \begin{align}
# E[x]=\sum_{x=1}^12 xP(x)=2\frac{1}{36}+3\frac{2}{36}+4\frac{3}{36}+5\frac{4}{36}+6\frac{5}{36}+7\frac{6}{36}+8\frac{5}{36}+9\frac{4}{36}+10\frac{3}{36}+11\frac{2}{36}+12\frac{1}{36}
# \end{align}
# \begin{align}
# =\frac{1}{36}(2+6+12+20+30+42+40+36+30+22+12)=\frac{1}{36}252=7
# \end{align}
#
# El valor esperado es 7
#
# b)
# \begin{align}
# E[X]=\int_{0}^{4}x(\frac{xy}{96})dx=\frac{y}{96}\frac{x^2}{2}|_{0}^{4}=\frac{16y}{192}
# \end{align}
# \begin{align}
# E[Y]=\int_{1}^{5}y(\frac{xy}{96})dy=\frac{x}{96}\frac{y^2}{2}|_{1}^{5}=\frac{25x}{192}-\frac{1x}{192}=\frac{24x}{192}
# \end{align}
# \begin{align}
# E[XY]=\int_{1}^{5}\int_{0}^{4}xy(\frac{xy}{96})dxdy=\int_{1}^{5}\frac{y}{96}\frac{x^2}{2}|_{0}^{4}=\int_{1}^{5}\frac{16x}{192}=\frac{16x^2}{384}|_{1}^{5}=\frac{400}{384}-\frac{16}{384}=\frac{384}{384}=1
# \end{align}
# \begin{align}
#     E[2x+3Y]=\int_{1}^{5}\int_{0}^{4}(2x+3y)(\frac{xy}{96})dxdy=\int_{1}^{5}\frac{2yx^3}{288}+\frac{3y^2x^2}{192}|_{0}^{4}dy=\int_{1}^{5}\frac{8y^3}{288}+\frac{48y^2}{192}=\frac{8y^4}{1152}+\frac{48y^3}{576}|_{1}^{5}
# \end{align}
# c)
#
# Media
# \begin{align}
# \tilde{u}=\int_{0}^{8}x(\frac{4x(9x-x^2)}{81})=\frac{36x^4}{243}-\frac{4x^5}{405}|_{0}^{8}=\frac{147456}{243}-\frac{131072}{405}=6411,13-323,63=6087,5
# \end{align}
#
# Mediana
#
# La mediana es el punto de los datos agrupados que deja el 50% de la población entre menos infinito y dicho punto
# \begin{align}
# \int_{-\infty}^{M_e}\frac{(4x)9-x^2}{81}=0.5
# \end{align}
#
# Pero la funcion es cero fuera del intervalo entre 0 y 8 por lo cual
# \begin{align}
# \int_{0}^{M_e}\frac{(4x)9-x^2}{81}=0.5  \rightarrow \int_{0}^{M_e}\frac{36x-4x3}{81}=0.5 \rightarrow \frac{18x^2-x^4}{81}|_{0}^{M_e}=0.5 \rightarrow \frac{18(M_e)^2-(M_e)^4}{81}=0.5  \rightarrow \frac{18(M_e)^2-(M_e)^4}{81}=0.5
# \end{align}
# Esta es una ecuación con cuatro raices, de las cuales ignoramos las negativas por estar en el rango donde la densidad es cero<br>
# Raices= 3.9,1.6
#
# Moda
#
# Es el punto donde se encuentra la mayor concentración de la población, o sea el punto máximo de la densidad
#
# Para hallar el máximo se deriva la funcion y se despeja igualandola a cero
# \begin{align}
# \frac{d}{dx}\frac{36x-4x^3}{81}=\frac{36-12x^2}{81}=0
# \end{align}
# Entonces despejamos
# \begin{align}
# -12x^2=-36 \rightarrow x=\sqrt(3)=1.73
# \end{align}

# %% [markdown]
# ##Punto 3
#
# a) Código crawler
#
# package SecondChance;
#
# import java.io.IOException;
# import java.net.Authenticator;
# import java.net.PasswordAuthentication;
# import java.util.ArrayList;
# import java.util.List;
#
# import org.jsoup.Jsoup;
# import org.jsoup.nodes.Document;
# import org.jsoup.nodes.Element;
# import org.jsoup.select.Elements;
#
# public class CrawlerTwo {
#
#
#
#
# 	public static void main(String[] args){
# 		crawler("http://unal.edu.co");
# 	}
#
# 	public static void crawler(String URL){
# 		//get useful information
# 		try {
#
# //			System.setProperty("http.proxySet", "true");
# //			Authenticator.setDefault(new ProxyAuthenticator("user", "password"));
# 			System.getProperties().put("http.proxyHost", "172.31.239.53");
# 			System.getProperties().put("http.proxyPort", "3128");
#
#
# 			Document doc = Jsoup.connect(URL).get();
# //			System.out.println(doc.toString());
# 			//if(doc.text().contains("research")){
# 				System.out.println(URL);
# 			//}
# 				//get all links and recursively call the processPage method
# 				Elements questions = doc.select("a");
# 				for(Element link: questions){
#
# 					if(link.attr("href").contains("unal.edu.co") && !urls.contains(link.attr("href"))){
# 						urls.add(link.attr("href"));
# 						crawler(link.attr("abs:href"));
# 					}
# 				}
# 				for(String a: urls){
# 					System.out.println(a);
# 				}
#
# 		} catch (IOException e) {
# 			// TODO Auto-generated catch block
# 			e.printStackTrace();
# 		}
# 		System.out.println("total "+urls.size());
# 	}
#
#
#
# }
#
# b) Estructura de datos
#
# /*
#  * To change this template, choose Tools | Templates
#  * and open the template in the editor.
#  */
# package edu.ucatolica.secondChance;
#
# /**
#  *
#  * @author s02e15
#  */
# public class NodoPage {
#     private String url;
#     private Integer posicion;
#     private NodoPage nodo;
#
#     public String getUrl() {
#         return url;
#     }
#
#     public void setUrl(String url) {
#         this.url = url;
#     }
#
#     public Integer getPosicion() {
#         return posicion;
#     }
#
#     public void setPosicion(Integer posicion) {
#         this.posicion = posicion;
#     }
#
#     public NodoPage getNodo() {
#         return nodo;
#     }
#
#     public void setNodo(NodoPage nodo) {
#         this.nodo = nodo;
#     }
#
# }
